# %% [markdown]
# # Song Recommendation

# %% [markdown]
# In this case, I make a Recommender Popularity-based recommendation system which is a custom function that accepts 3 arguments: dataset, recommended number of songs, and minimum number of song ratings that will allow us to find a top 10 songs recommendation.

# %% [markdown]
# Also, I create a users collaborative filtering recommendation system in the form of a custom function that accepts 4 arguments: dataset, user id, number of recommended songs, and algorithm that will allow us to find the top 10 songs recommendation for a single user. with the recommendations given are songs that have not been rated by the user.

# %% [markdown]
# The sections of this project are:
#
# 1. Data Cleansing & Preparation
# 2. Find a top 10 songs recommendation
# 3. Recommender Model Building for a top 10 songs recommendation for single user

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
from surprise import KNNBasic, Dataset, Reader, accuracy
from surprise.model_selection import train_test_split as tts_surprise
from surprise.model_selection import GridSearchCV as gscv_surprise

# %% [markdown]
# # 1. Data Cleansing & Preparation

# %% [markdown]
# input the dataset

# %%
song = pd.read_csv('song_quarter.csv')
song.head()
# Out:
#    song_id                             title         artist_name  user_id  \
# 0     3165                       Mockingbird              Eminem    20852
# 1     6263  Here We Go Again (Album Version)            Paramore    24713
# 2     8518                      Love Is Here  Tenth Avenue North    72102
# 3     5706                           Mykonos         Fleet Foxes    44037
# 4      859        Stroke You Up (LP Version)      Changing Faces     8557
#
#    rating
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0

# %% [markdown]
# quick look the data

# %%
song.duplicated().sum()
# Out:
# 0

# %% [markdown]
# no duplicated data

# %%
song.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21736 entries, 0 to 21735
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      21736 non-null  int64
#  1   title        21736 non-null  object
#  2   artist_name  21736 non-null  object
#  3   user_id      21736 non-null  int64
#  4   rating       21736 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 849.2+ KB

# %% [markdown]
# no missing values

# %% [markdown]
# # 2. Find a top 10 songs recommendation

# %% [markdown]
# first, I build a dictionaries with contents is song id, title, and artist name

# %%
inc = []
song_dict = {}
for x, y, z in zip(song['song_id'], song['title'], song['artist_name']):
    if x not in inc:
        song_dict[x] = y, z
        inc.append(x)

# %%
song_dict
# Out:
# {3165: ('Mockingbird', 'Eminem'),
#  6263: ('Here We Go Again (Album Version)', 'Paramore'),
#  8518: ('Love Is Here', 'Tenth Avenue North'),
#  5706: ('Mykonos', 'Fleet Foxes'),
#  859: ('Stroke You Up (LP Version)', 'Changing Faces'),
#  1891: ('Loud Pipes', 'Ratatat'),
#  2764: ('Lesson Learned', 'Ray LaMontagne'),
#  4160: ('How You Remind Me', 'Nickelback'),
#  8392: ('Aerodynamic (Daft Punk Remix)', 'Daft Punk'),
#  2679: ('Sidewinder (Album Version)', 'Avenged Sevenfold'),
#  8269: ('Naughty Girl', 'Beyoncé'),
#  3291: ('Michael', 'Soltero'),
#  3389: ('The Nest', 'José González'),
#  9562: ('Riverside', 'Sidney Samson'),
#  2030: ("Ball Of Confusion (That's What The World Is Today)",
#   'The Temptations'),
#  3564: ('Fuck Kitty', 'Frumpies'),
#  4684: ('Swagger', 'Flogging Molly'),
#  652: ('Charlotte Sometimes', 'The Cure'),
#  7381: ('The Rain', 'DMX'),
#  1331: ('Para Hacerme Perdonar (En Vivo Teatro Metropolitan)', 'Ely Guerra'),
#  8091: ('Passion', 'Gat Décor'),
#  5062: ('Re: Your Brains', 'Jonathan Coulton'),
#  3110: ('Double Bass', 'Gorillaz'),
#  9349: ('All For Swinging You Around', 'The New Pornographers'),
#  5917: ('Straight To The Bank', '50 Cent'),
#  1271: ('Moondance (Album Version)', 'Michael Bublé'),
#  5299: ('Californication (Album Version)', 'Red Hot Chili Peppers'),
#  9634: ('Heavens Above', 'The Style Council'),
#  8648: ('Bar Tacuba', 'Café Tacvba'),
#  9936: ('LoveGame', 'Lady GaGa'),
#  8178: ('Polite Dance Song', 'the bird and the bee'),
#  2521: ('The Universal', 'Blur'),
#  7977: ('Speed Of Sound', 'Coldplay'),
#  6935: ('Billy Breathes', 'Phish'),
#  3584: ('You Fight Me', 'Breaking Benjamin'),
#  3486: ('Cuts Like A Knife', 'Bryan Adams'),
#  4743: ('Helena (So Long & Goodnight) (Album Version)', 'My Chemical Romance'),
#  3080: ('Safety Dance', 'Men Without Hats'),
#  16: ('STARSTRUKK [FEATURINGKATYPERRY] (Explicit Bonus Version)', '3OH!3'),
#  8612: ('Fix You', 'Coldplay'),
#  9462: ('Audience Of One', 'Rise Against'),
#  4629: ('I Never Told You', 'Colbie Caillat'),
#  3727: ('Gone', 'Jack Johnson'),
#  7562: ('Coda', 'Chris Bathgate'),
#  8160: ('Kissy Kissy', 'The Kills'),
#  8745: ('Microdaze', 'Jonny L'),
#  8927: ("What's Happenin'", 'Method Man / Busta Rhymes'),
#  1178: ('Monkey Gone To Heaven', 'Pixies'),
#  7259: ('Matricide', 'Nevermore'),
#  2710: ('Everyday Struggle (Album Version)', 'The Notorious B.I.G.'),
#  9606: ('MEIN TEIL', 'Rammstein'),
#  8637: ('Gold Lion', 'Yeah Yeah Yeahs'),
#  5277: ('More Than A Feeling', 'Boston'),
#  2372: ('One Summer Night', 'The Danleers'),
#  1037: ('Latin America', 'Holy Fuck'),
#  6074: ('Forgot About Dre', 'Dr. Dre / Eminem'),
#  9904: ('Aerials', 'System of a Down'),
#  5017: ('No Ceiling', 'Eddie Vedder'),
#  9348: ('Wasting Time', 'Jack Johnson'),
#  6183: ('Chapel Of Ghouls (Live)', 'Morbid Angel'),
#  2258: ('Silver Bath', 'Plastic Boy'),
#  44: ('Combat Rock', 'Sleater-kinney'),
#  1026: ('More Than Words', 'Extreme'),
#  5155: ('Pace Is The Trick', 'Interpol'),
#  7296: ('You Only Live Twice (Live From Norway)', 'Coldplay'),
#  2471: ('OVO MI JE `KOLA', 'Gibonni'),
#  3665: ('Sweet Baby James', 'James Taylor'),
#  539: ("There's A Good Reason These Tables Are Numbered Honey_ You Just Haven't Thought of It Yet [Live In Chicago]",
#   'Panic At The Disco'),
#  475: ('Australia', 'Jonas Brothers'),
#  8581: ('I Am A Man Of Constant Sorrow', 'The Soggy Bottom Boys'),
#  2224: ("We Don't Care", 'Kanye West'),
#  2357: ('Signos', 'Soda Stereo'),
#  2770: ('The Black Pearl', 'Klaus Badelt'),
#  2709: ("Fuck It (I Don't Want You Back)", 'Eamon'),
#  8377: ('Be Aggressive', 'Faith No More'),
#  168: ('Been A Son', 'Nirvana'),
#  4008: ("It's My Life", 'Talk Talk'),
#  9640: ('Waltz #2 (XO)', 'Elliott Smith'),
#  6418: ('American Terrorist [feat. Matthew Santos] (Explicit Album Version)',
#   'Lupe Fiasco'),
#  6635: ('El duelo', 'La Ley'),
#  2060: ('Drugs', 'Ratatat'),
#  1160: ('Here Comes The Monkey', 'The Hawaiians'),
#  3768: ('Just The Two Of Us (WSM Compilation Edit)',
#   'Grover Washington Jr. feat. Bill Withers'),
#  4713: ('Overboard', 'Justin Bieber / Jessica Jarrell'),
#  2525: ('Why Do I Keep Counting?', 'The Killers'),
#  2346: ('Waiting For Tonight', 'Jennifer Lopez'),
#  8873: ('Transmission', 'Joy Division'),
#  2875: ("Starin' Through My Rear View", '2Pac'),
#  5619: ('Laffy Taffy (Amended Album Version)', 'D4L'),
#  5766: ('Old Song', 'Max Richter'),
#  8617: ('Dance With Somebody', 'Mando Diao'),
#  2005: ('Everybody Be Somebody', 'Thomas Gold & Matthias Menck'),
#  4690: ("Buzzin'", 'Shwayze'),
#  750: ('Constellations', 'Jack Johnson'),
#  3950: ('Born To Run', 'Bruce Springsteen'),
#  6730: ('Get On Your Boots', 'U2'),
#  5894: ('Caring Is Creepy', 'The Shins'),
#  6249: ('The Bad Touch', 'Bloodhound Gang'),
#  1699: ('Army of Me', 'Björk'),
#  587: ('Nightlite (Zero dB Reconstruction - Radio Edit)',
#   'Bonobo feat.  Bajka'),
#  7187: ('Long Black Veil', 'DAVE MATTHEWS BAND'),
#  9641: ('Neon Tiger', 'The Killers'),
#  3599: ('Way Out of Here [Album Version]', 'Porcupine Tree'),
#  3903: ('Tribal War', 'Buju Banton'),
#  4400: ('KissKiss', 'Parov Stelar'),
#  3549: ('Common Denominator', 'Justin Bieber'),
#  3791: ('Warning (Album Version)', 'The Notorious B.I.G.'),
#  817: ('Hey', 'Pixies'),
#  4289: ('Do You Remember', 'Jack Johnson'),
#  9173: ('Leve Com Você', 'Natiruts'),
#  810: ('We Have Love', 'Hot Chip'),
#  4355: ('Slang Blade', 'Binary Star'),
#  6483: ('Stickwitu', 'The Pussycat Dolls'),
#  28: ("Who's That Girl (Soundtrack Album Version)", 'Madonna'),
#  7372: ('No Air duet with Chris Brown', 'Jordin Sparks featuring Chris Brown'),
#  3365: ('Talamak', 'Toro Y Moi'),
#  2464: ('Goodnight And Goodbye', 'Jonas Brothers'),
#  7073: ('Be Aware', 'Bobby Lee'),
#  7347: ('Bounce That', 'Girl Talk'),
#  8624: ('Hearts On Fire', 'Cut Copy'),
#  2934: ('Stack Shot Billy', 'The Black Keys'),
#  3658: ('Flume', 'Bon Iver'),
#  8145: ('Observándonos (Satélites)', 'Soda Stereo'),
#  5795: ('Coffee Shop Soundtrack', 'All Time Low'),
#  4439: ('Elävät ja kuolleet', 'Haloo Helsinki!'),
#  3421: ("Just Ain't Gonna Work Out", 'Mayer Hawthorne'),
#  3468: ('These Days', '3 Doors Down'),
#  8434: ('Howlin\x19 For You', 'The Black Keys'),
#  1610: ("Can't Believe (Album Version)",
#   'Faith Evans (Featuring Carl Thomas)'),
#  378: ('Santa Monica', 'Theory Of A Deadman'),
#  9145: ('Scream For More', 'Kate Ryan'),
#  6083: ('All Falls Down', 'Kanye West / Syleena Johnson'),
#  7012: ('Big Calm', 'Morcheeba'),
#  4122: ('I Feel Just Like a Child', 'Devendra Banhart'),
#  9211: ('Me Amo', 'El Cuarteto De Nos'),
#  2470: ('Drum Song', 'The Temper Trap'),
#  256: ('Common Pleasure [Eagles Ballroom Live Version]', 'Jason Mraz'),
#  3589: ('Hazy Shade Of Winter', 'Bangles'),
#  4729: ('Honey And The Moon [Radio Edit]', 'Joseph Arthur'),
#  4649: ('Top Yourself', 'The Raconteurs'),
#  5076: ('Eli_ The Barrow Boy', 'The Decemberists'),
#  4407: ('Louie Louie', 'The Kingsmen'),
#  7127: ('Laundry Room', 'The Avett Brothers'),
#  915: ('Not Fade Away', 'The Rolling Stones'),
#  2784: ('My Girl Is Calling Me a Liar', 'Chromeo'),
#  5278: ('Loving You [Album Version]', 'Paolo Nutini'),
#  6840: ('Harmony One', 'Four Tet'),
#  7663: ('Infinity', 'The xx'),
#  9091: ('REISE_ REISE', 'Rammstein'),
#  8726: ('One Time', 'Jill Scott'),
#  5959: ('Those Dancing Days Are Gone (Album)', 'Carla Bruni'),
#  6377: ('Shake A Tail Feather', 'The Cheetah Girls'),
#  7224: ('Victoria (LP Version)', "Old 97's"),
#  777: ('Miss Murder', 'AFI'),
#  6878: ('Ready For The Floor (Album Version)', 'Hot Chip'),
#  3552: ('Walk On', 'U2'),
#  3164: ('In The Flesh', 'Blondie'),
#  2768: ('The Girl', 'City And Colour'),
#  3280: ('Old Man Time (Album Version)', 'O.A.R.'),
#  8438: ('Skin Is_ My', 'Andrew Bird'),
#  5620: ('Above The Clouds (Edited)', 'Gang Starr/Inspectah Deck'),
#  8361: ('Call The Doctor', 'Sleater-kinney'),
#  4076: ('Grown So Ugly', 'The Black Keys'),
#  8723: ("Hymne A L'Amour (Album Version)", 'Josh Groban'),
#  5229: ('Come Fly With Me (Album Version)', 'Michael Bublé'),
#  9123: ('Drop', 'The Pharcyde'),
#  2504: ('Only', 'Nine Inch Nails'),
#  6697: ('Everybody Know', 'Guts'),
#  9777: ('Big Trouble', 'Man Man'),
#  1519: ('Deny Selected', 'Boys Noize'),
#  9525: ('Rhythm Of The Night', 'Corona'),
#  4852: ('Naive', 'The Kooks'),
#  9299: ('Personal Jesus', 'Depeche Mode'),
#  7794: ('One Call Away', 'Chingy Featuring J/Weav'),
#  6186: ('Who Wants To Live Forever (With Commentary)', 'Queen'),
#  2207: ('Kids Of The Future', 'Jonas Brothers'),
#  267: ('That Was Just A Dream', 'Cut Copy'),
#  1350: ('Medley:  Amanda/A Couple More Years', 'Waylon Jennings'),
#  3750: ('Rec & Play', "I'm From Barcelona"),
#  3979: ('Chemo Limo (Remastered Version)', 'Regina Spektor'),
#  7249: ('Milk', 'Garbage'),
#  776: ('Every Morning', 'Basshunter'),
#  1210: ('Boombox', 'The Lonely Island / Julian Casablancas'),
#  4464: ('The Pulse', 'Digitalism'),
#  8658: ('Call To Arms', 'Angels and Airwaves'),
#  9159: ('Careless Whisper', 'George Michael'),
#  5518: ('(Remember The Days Of The) Old Schoolyard', 'Cat Stevens'),
#  8649: ('I Stand Alone', 'Godsmack'),
#  7177: ('Welcome To The Masquerade', 'Thousand Foot Krutch'),
#  5893: ("I'm Real", 'Jennifer Lopez featuring Ja Rule'),
#  6709: ('Movement', 'LCD Soundsystem'),
#  2977: ('Ante Up (Robbin Hoodz Theory)', 'M.O.P.'),
#  6794: ("It's Me B*#@hes", 'Swizz Beatz'),
#  1373: ('Reckless', 'Crystal Castles'),
#  6015: ("Runnin'", 'The Pharcyde'),
#  951: ('A Little Something', 'Casual featuring Del Tha Funkee Homosapien'),
#  2280: ('Don', 'Miranda!'),
#  4477: ('For Tomorrow', 'Blur'),
#  1800: ('Down To The Well', 'Pixies'),
#  6375: ('Second To None', 'Phoenix'),
#  45: ('Speed', 'Yahel'),
#  3947: ('On Bended Knee', 'Boyz II Men'),
#  9459: ("Hang 'Em High (Album Version)", 'My Chemical Romance'),
#  7922: ('Better Days', 'Amos Lee'),
#  5114: ('Piazza_ New York Catcher', 'Belle and Sebastian'),
#  5189: ('Damage Inc.', 'Metallica'),
#  1033: ('Shadow Of A Man', 'Bedouin Soundclash'),
#  6529: ('aNYway', 'Armand Van Helden & A-TRAK Present Duck Sauce'),
#  804: ('Love Is A Place', 'Metric'),
#  2687: ('Porterville', 'Creedence Clearwater Revival'),
#  2778: ('John The Fisherman', 'Primus'),
#  574: ('How Come', 'D-12'),
#  9873: ('A Primera Vista', 'Pedro Aznar'),
#  2212: ('Sing_ Sing_ Sing (Key-E-Premiere Performance Plus w/o Background Vocals)',
#   'Chris Tomlin'),
#  493: ('The Alliance Of Hellhoundz', 'DESTRUCTION'),
#  8002: ('People Gotta Move', 'Gino Vannelli'),
#  9194: ('No Llegas A Mí', 'No Te Va Gustar'),
#  2118: ('Meet Virginia', 'Train'),
#  5390: ('Frijolero', 'Molotov'),
#  3726: ('Lose My Soul feat. Kirk Franklin & Mandisa / Afterparty', 'tobyMac'),
#  9445: ('The Marbled Godwit', 'Bowerbirds'),
#  3525: ('Hell On The Heart', 'Eric Church'),
#  3888: ('MOSKAU', 'Rammstein'),
#  1757: ('The Earth Is (Album Version)', 'Air Supply'),
#  2645: ('Unwritten', 'Natasha Bedingfield'),
#  4567: ('One In A Million', "Guns N' Roses"),
#  4694: ('Ready Or Not', 'The Fugees'),
#  503: ('All We Are', 'OneRepublic'),
#  7228: ('Here I Am To Worship (Here I Am To Worship Album Version)',
#   'Tim Hughes'),
#  6404: ('She (Album Version)', 'Green Day'),
#  2081: ('The Reeling', 'Passion Pit'),
#  9921: ('A Little Less Sixteen Candles_ A Little More "Touch Me',
#   'Fall Out Boy'),
#  3999: ('FU-GEE-LA', 'Fugees'),
#  2946: ('Pussy', 'Brazilian Girls'),
#  4823: ('Waking Up', 'OneRepublic'),
#  8657: ('Shake A Fist', 'Hot Chip'),
#  1269: ('Shine', 'David Gray'),
#  2706: ("I'm Not In Love", 'Charly García'),
#  9759: ('Tomorrow Comes Today', 'Gorillaz'),
#  9534: ('Eco', 'Jorge Drexler'),
#  2643: ("Let's Shake Hands", 'The White Stripes'),
#  365: ('Like A Rolling Stone', 'Bob Dylan'),
#  4095: ('My Maria', 'Brooks & Dunn'),
#  5486: ('D.O.A. Part 2', 'Ignition'),
#  2241: ('Selling The Drama', 'Live'),
#  4221: ('I Could Have Lied (Album Version)', 'Red Hot Chili Peppers'),
#  4302: ('Keep The Change_ You Filthy Animal', 'All Time Low'),
#  4403: ('Tranquilize', 'The Killers / Lou Reed'),
#  8224: ('Your Star', 'The All-American Rejects'),
#  4237: ("I?'m A Steady Rollin? Man", 'Robert Johnson'),
#  9595: ('Highway Star', 'Deep Purple'),
#  1499: ('Method Man', 'Wu-Tang Clan'),
#  398: ('Planet 7', 'System 7'),
#  560: ('Purple Weed', 'Mondo Marcio'),
#  1672: ('Shadows Of Ourselves', 'Thievery Corporation'),
#  950: ('Disconnect_ Disconnect', 'Osker'),
#  1998: ('Plasticities (Remix)', 'Andrew Bird'),
#  7615: ('Scream', 'Michael Jackson'),
#  3047: ('Dream', 'Iration'),
#  2294: ('Too Little_ Too Late', 'JoJo'),
#  9711: ('Cat And Mouse', 'The Red Jumpsuit Apparatus'),
#  708: ('The Killing Moon', 'Echo And The Bunnymen'),
#  7379: ('Nice Weather For Ducks', 'Lemon Jelly'),
#  8872: ('Body In A Box', 'City And Colour'),
#  7879: ('Empire State Of Mind (Part II) Broken Down', 'Alicia Keys'),
#  8939: ("Tears Don't Fall", 'Bullet For My Valentine'),
#  7362: ('The Best Thing', 'Relient K'),
#  4528: ('Asche Zu Asche', 'Rammstein'),
#  4506: ('Lovely Ladies', 'Les Misérables - 10th Anniversary Concert'),
#  7662: ('The Resistance', 'Anberlin'),
#  3274: ('Warrior', 'Yeah Yeah Yeahs'),
#  5769: ('Limelight', 'Rush'),
#  6045: ('The Bones Of An Idol', 'The New Pornographers'),
#  1172: ("It Don't Matter", 'Donavon Frankenreiter'),
#  6315: ('You Don\x19t Understand Me', 'The Raconteurs'),
#  3705: ('Lucille', 'Kenny Rogers'),
#  9153: ('Matenme Porque Me Muero', 'Caifanes'),
#  874: ('Ein Schiff Wird Kommen...', 'Lale Andersen'),
#  7961: ("I Don't Do Crowds", 'Camera Obscura'),
#  7876: ('Que Tengo Que Hacer', 'Daddy Yankee'),
#  6685: ('Waiting For A Dream', 'Rufus Wainwright'),
#  160: ('Clouds (Of Color Bright Album Version)', 'Velour 100'),
#  4754: ('Sympathy', 'Sleater-kinney'),
#  2792: ('Lucky Me', 'Chris Brown'),
#  7928: ('Arizona', 'Kings Of Leon'),
#  7735: ("Death Cult Soup n' Salad", 'Almighty Defenders'),
#  3216: ('A Day Without Me', 'U2'),
#  3361: ('Hardcore', 'Redman'),
#  4063: ('5 Minutes Alone [Live Version]', 'Pantera'),
#  5097: ('The Fight Song', 'Marilyn Manson'),
#  3598: ('La Tripleta', 'Calle 13'),
#  3032: ('I Miss You', 'Incubus'),
#  4023: ('Yellow Ledbetter', 'Pearl Jam'),
#  1316: ('Entre Dos Tierras (2000 Digital Remaster)', 'Héroes del Silencio'),
#  3370: ('Island', 'The Whitest Boy Alive'),
#  1388: ('Dream About Flying', 'Alexi Murdoch'),
#  7511: ("Summer's End", 'Foo Fighters'),
#  7406: ('Give It All', 'Rise Against'),
#  2217: ('One Of The Boys', 'Katy Perry'),
#  1310: ('Si Te Vas', 'Marc Anthony'),
#  4446: ('Too Drunk Too F****', 'Nouvelle Vague'),
#  1050: ('Wet Blanket', 'Metric'),
#  2749: ('Amazing Grace (1999 Digital Remaster)', 'Bryan Ferry'),
#  3483: ('I Got You', 'Train'),
#  7845: ('O Segundo Sol', 'Nando Reis'),
#  7266: ('Aguas De Marco', 'João Gilberto'),
#  3902: ('The Shrew', 'Beirut'),
#  110: ('Cancer', 'Sick Puppies'),
#  2256: ('Hand On Your Heart', 'José González'),
#  3398: ('Cold Water', 'Damien Rice'),
#  8867: ("The Sun Ain't Gonna Shine Anymore", 'Walker Brothers'),
#  9775: ('Surrender', 'Cheap Trick'),
#  9384: ('Saying Sorry (Album Version)', 'Hawthorne Heights'),
#  6428: ('Habana', 'Orishas'),
#  6006: ("Let's Go All The Way (Short Blix Mix)", 'Sly Fox'),
#  2990: ('Right Down The Line', 'Gerry Rafferty'),
#  7775: ('Weenie Beenie', 'Foo Fighters'),
#  9105: ('Rest', 'The Temper Trap'),
#  6784: ('Mad World', 'Tears For Fears'),
#  6852: ('June Evenings', 'Air France'),
#  995: ('Kept It Too Real (Amended Album Version)', 'Plies'),
#  2621: ('Excuse Me Mr.', 'No Doubt'),
#  5421: ('The Guillotine (Album Version)', 'Escape The Fate'),
#  2104: ('Skulls', 'The Misfits'),
#  1042: ('Numb', 'Sia'),
#  6095: ('Take It Easy (love Nothing) (Album Version)', 'Bright Eyes'),
#  4176: ('Romanticótico', 'Cuentos Borgeanos'),
#  8861: ('Corn Bread', 'DAVE MATTHEWS BAND'),
#  9000: ('Cheating On You', 'Franz Ferdinand'),
#  6633: ('¡Viva La Gloria! (Album Version)', 'Green Day'),
#  4267: ('Stop', 'Ryan Adams'),
#  7749: ('Blood Red', 'Slayer'),
#  761: ('People Got To Be Free', 'The Rascals'),
#  108: ('Heartbreaker/"If You Should Ever Be Lonely', 'Mariah Carey'),
#  2068: ('Peace Of Mind', 'Boston'),
#  340: ('Make Gay Love Not War', 'Need New Body'),
#  7978: ('Unrecorded', 'M83'),
#  8999: ("I've Got The World On A String", 'Michael Bublé'),
#  1914: ("Willie O'Winsbury", 'Meg Baird'),
#  2055: ('Esa noche', 'Café Tacvba'),
#  7435: ('Ghost Of Yesterday (2001 Digital Remaster)',
#   'The George Shearing Quintet with Nancy Wilson'),
#  7602: ('Dream', 'Priscilla Ahn'),
#  1879: ('Spill The Wine', 'Eric Burdon'),
#  3756: ('Confessions', 'Usher'),
#  8127: ('Kalopsia', 'Mark Otten'),
#  3282: ("The Lighthouse's Tale", 'Nickel Creek'),
#  4866: ('Nothing On But The Radio', 'Gary Allan'),
#  1308: ('Pedro Navaja (Live LP Version)', 'Ruben Blades'),
#  6111: ('Save Me (LP Version)', 'Remy Zero'),
#  5629: ('Some Velvet Morning', 'Primal Scream;Kate Moss'),
#  7465: ('I Have Seen', 'Zero 7'),
#  593: ('East Northumberland High', 'Miley Cyrus'),
#  4741: ('Electric Twist', 'A Fine Frenzy'),
#  9189: ('Guinnevere [Remastered LP Version]', 'Crosby_ Stills & Nash'),
#  6882: ('City Of Angels', 'The Distillers'),
#  3224: ('Harold T. Wilkins_ or How to Wait for a Very Long Time', 'Fanfarlo'),
#  6449: ('Into The Fire', 'Thirteen Senses'),
#  980: ('Heard Them Stirring', 'Fleet Foxes'),
#  5832: ('Chapter Four', 'Avenged Sevenfold'),
#  6408: ('Yellow Sun', 'The Raconteurs'),
#  371: ('All Night', 'Damian Marley / Stephen Marley'),
#  4254: ("I'm the man who loves you", 'Wilco'),
#  3583: ('Gel (LP Version)', 'Collective Soul'),
#  1540: ('Stratus [The Bottom Shelf]', 'Tommy Bolin'),
#  8072: ('(Splash) Turn Twist', 'Jimmy Eat World'),
#  2978: ('Music And Lights', 'Imagination'),
#  9412: ('Been Around The World (Featuring The Notorious B.I.G. & Mase)(Album Version)',
#   'Puff Daddy'),
#  9319: ('Up And Up (Acoustic)', 'Relient K'),
#  7807: ("If I Can't Have You", 'Mount Sims'),
#  8448: ("You Ain't Seen Nothing Yet", 'Bachman-Turner Overdrive'),
#  4312: ('Sura (2008 Digital Remaster)', 'CCCP - Fedeli Alla Linea'),
#  5762: ('Saints And Sailors', 'Dashboard Confessional'),
#  3669: ('Six-Pack Summer', 'Phil Vassar'),
#  3104: ('Beauty School (Album Version)', 'Deftones'),
#  295: ('Mutt', 'Blink-182'),
#  4018: ('All Over Me', 'Josh Turner'),
#  6563: ("Warrior's Dance", 'The Prodigy'),
#  9558: ('The Stallion', 'Ween'),
#  6466: ("It's Raining Men (Radio Edit)", 'Geri Halliwell'),
#  8561: ('Flowing', '311'),
#  5812: ('If I Ever Leave This World Alive', 'Flogging Molly'),
#  8108: ('July Jones', 'The New Pornographers'),
#  5266: ("Bootstrap's Bootstraps", 'Klaus Badelt'),
#  8685: ('A Year', 'Loudon Wainwright III'),
#  8920: ('Kill The King', 'Megadeth'),
#  2479: ('Entertainment', 'Rise Against'),
#  6844: ('Let My Love Open The Door (Underdog Album Version)',
#   'Audio Adrenaline'),
#  1713: ('Heaven Beside You', 'Alice In Chains'),
#  7015: ('Dear Maria_ Count Me In', 'All Time Low'),
#  4647: ('Top Drawer', 'Man Man'),
#  7828: ('Kiss Me (Album Version)', 'Cassie'),
#  3267: ("Takin' Care Of Business", 'Bachman Turner Overdrive'),
#  9115: ('Got No Love', 'The Kooks'),
#  2312: ('Another Great Divide', 'Split Enz'),
#  315: ('Frente A Frente', 'Bunbury'),
#  4044: ('Afternoon (Album)', 'Carla Bruni'),
#  5738: ('Peces', 'Francisca Valenzuela'),
#  8346: ('Walk Through Hell (featuring Max Bemis Acoustic Exclusive)',
#   'Say Anything'),
#  9639: ('Big Booty Hoes (Featuring Too $hort) (Album Version)',
#   'The Notorious B.I.G.'),
#  7480: ('Everywhere', 'Yellowcard'),
#  1169: ('Il tempio interiore', 'Gino Fioravanti_ Gianluigi Toso'),
#  4689: ('Intro', 'Jay-Z'),
#  8259: ('Side', 'Travis'),
#  3081: ('Homeward Bound', 'Simon & Garfunkel'),
#  864: ('Attention', 'The Raconteurs'),
#  6035: ('Down With The Sickness (Album Version)', 'Disturbed'),
#  6728: ('Three Hopeful Thoughts', 'Rilo Kiley'),
#  1863: ('House By the Sea (Album)', 'Iron And Wine'),
#  6348: ('Collide (Album Version)', 'Skillet'),
#  5759: ('Un Violinista En Tu Tejado', 'Melendi'),
#  3758: ('Seaside', 'The Kooks'),
#  4085: ('Georgia On My Mind (Album Version)', 'Michael Bublé'),
#  1698: ('Remember When It Rained (Revised Live Version)', 'Josh Groban'),
#  6272: ('Days Go By', 'Dirty Vegas'),
#  9359: ('Century', 'Tiësto feat. Calvin Harris'),
#  2351: ('Cult Status', '1990s'),
#  9064: ('I Told You So', 'Carrie Underwood'),
#  7147: ('Red Cave', 'Yeasayer'),
#  9956: ('Beautiful', 'India.Arie'),
#  3436: ('Pap Smear', 'Crystal Castles'),
#  8916: ('First Time', 'Offer Nissim'),
#  320: ('Les derniers aventuriers', 'La Rue Ketanou'),
#  9605: ('Primera Vez', 'Ricardo Arjona'),
#  5098: ('The Handshake', 'MGMT'),
#  8650: ('Too Drunk to Fuck', 'Dead Kennedys'),
#  9330: ('Backdoor Love Affair (LP Version)', 'ZZ Top'),
#  3943: ('My Baby Left Me', 'Creedence Clearwater Revival'),
#  1733: ('Eat It', 'Weird Al Yankovic'),
#  6142: ('Congratulations', 'Traveling Wilburys'),
#  98: ('Headlong', 'Queen'),
#  9248: ('White Knuckles', 'Five Finger Death Punch'),
#  8887: ('Surfing With The Alien', 'Joe Satriani'),
#  1710: ('Chevy Smile (featuring Trick Daddy_ Block & Jazze Pha) (Amended Album Version)',
#   'Yung Joc feat Trick Daddy_ Block & Jazze Pha'),
#  4385: ('Orishas Llego', 'Orishas'),
#  2608: ('Near To You', 'A Fine Frenzy'),
#  5093: ('After The Gold Rush (Album Version)', 'Neil Young'),
#  156: ('Como Brillaba tu Alma', 'No Te Va Gustar'),
#  2993: ('Mary Jane (Acoustic Album Version)', 'Alanis Morissette'),
#  6689: ('I Remember', 'Damien Rice'),
#  111: ('Surrounded', 'Dream Theater'),
#  9290: ('Over The Rainbow', 'Eva Cassidy'),
#  2066: ("Can't Deny It [featuring Nate Dogg] [Explicit Version]", 'Fabolous'),
#  3185: ('Big Casino', 'Jimmy Eat World'),
#  5950: ('Make A Mistake', 'Brad Paisley'),
#  4328: ("Party At A Rich Dude's House", 'Ke$ha'),
#  7482: ('1991', 'Crystal Castles'),
#  8498: ("What's Luv? (Featuring Ja-Rule & Ashanti) (Explicit Album Version)",
#   'Fat Joe'),
#  7051: ('Dead Presidents II', 'Jay-Z'),
#  7201: ('Vision One', 'Royksopp'),
#  634: ('The Outer Banks', 'The Album Leaf'),
#  768: ('Meatplow (LP Version)', 'Stone Temple Pilots'),
#  1199: ('Meanwhile_ Rick James...', 'Cake'),
#  6077: ('Cry No More', 'Buju Banton'),
#  4679: ('One more night (your ex-lovers remains dead)', 'Stars'),
#  4487: ('Ring Of Fire', 'Social Distortion'),
#  4353: ('Change Down / The Sugar Rhyme', 'Bonobo'),
#  9614: ('Brain (Edited)', 'N.E.R.D.'),
#  9100: ('Mayday!!!', 'Flobots'),
#  6140: ('Whalebones', 'Man Man'),
#  4945: ('Collecting Skylines', 'Swearing At Motorists'),
#  5074: ('Space Cowboy (Digitally Remastered 90)', 'Steve Miller Band'),
#  8529: ('Goodbye For Now (Album Version)', 'P.O.D.'),
#  9805: ('I Was Once_ Possibly_ Maybe_ Perhaps A Cowboy King (feat. NO)',
#   'Asking Alexandria'),
#  6761: ('Take Care', 'Beach House'),
#  8164: ('Falling Down', 'Muse'),
#  1367: ('Just Another Star', 'Bullet For My Valentine'),
#  4236: ('Frankly_ Mr. Shankly', 'The Smiths'),
#  2888: ('Put A Penny In The Slot', 'Fionn Regan'),
#  2972: ('Ort', 'Cows'),
#  8862: ('Magic (LP Version)', 'The Cars')}

# %% [markdown]
# then, build a dataframe that we need which is the dataset, recommended number of songs, and minimum number of song ratings

# %%
rating_mean = song.groupby('song_id').mean()
rating_count = song.groupby('song_id').count()

# %%
song_df = rating_mean.join(rating_count, lsuffix='_mean', rsuffix='_count').drop(['user_id_mean','user_id_count', 'artist_name', 'title'], axis=1).reset_index()
song_df.head()
# Out:
#    song_id  rating_mean  rating_count
# 0       16     1.186047           172
# 1       28     1.464286            28
# 2       44     1.000000            21
# 3       45     1.000000            34
# 4       98     1.000000            22

# %% [markdown]
# Build a Recommender system

# %%
def pop_recom(df, thre, n):
    df_recom = df.copy(deep=True)
    ori_title = []
    for id in df_recom['song_id']:
        ori_title.append(song_dict[id])
    df_recom['title'] = ori_title
    
    df_recom = df_recom[df_recom['rating_count'] < thre]
    return df_recom.sort_values('rating_mean', ascending=False).iloc[:n]

# %% [markdown]
# Let's test our recommender system for top 10 recommendation songs!

# %%
pop_recom(song_df, 100, 10)
# Out:
#      song_id  rating_mean  rating_count  \
# 385     8346     1.782609            23
# 293     6183     1.772727            22
# 111     2471     1.736842            19
# 33       761     1.650000            20
# 53      1160     1.640000            25
# 378     8145     1.630952            84
# 205     4176     1.625000            16
# 71      1540     1.600000            15
# 42       874     1.583333            12
# 218     4400     1.578947            57
#
#                                                  title
# 385  (Walk Through Hell (featuring Max Bemis Acoust...
# 293            (Chapel Of Ghouls (Live), Morbid Angel)
# 111                         (OVO MI JE `KOLA, Gibonni)
# 33                (People Got To Be Free, The Rascals)
# 53              (Here Comes The Monkey, The Hawaiians)
# 378           (Observándonos (Satélites), Soda Stereo)
# 205                 (Romanticótico, Cuentos Borgeanos)
# 71           (Stratus [The Bottom Shelf], Tommy Bolin)
# 42          (Ein Schiff Wird Kommen..., Lale Andersen)
# 218                           (KissKiss, Parov Stelar)

# %% [markdown]
# # 3. Recommender Model Building for a top 10 songs recommendation for single user

# %%
song_us = song.drop(['artist_name', 'title'], axis=1)
song_us.head()
# Out:
#    song_id  user_id  rating
# 0     3165    20852     1.0
# 1     6263    24713     1.0
# 2     8518    72102     1.0
# 3     5706    44037     1.0
# 4      859     8557     1.0

# %%
reader = Reader(rating_scale=(0,5))
data = Dataset.load_from_df(song_us, reader)
trainset, testset = tts_surprise(data, test_size=0.2, random_state=42)

# %%
param_grid = {'k': [10, 20, 30],
             'min_k': [3, 6, 9],
             'sim_options': {'name': ['msd', 'pearson', 'cosine'], 'user_based': [True]}}

gscv = gscv_surprise(KNNBasic, param_grid, cv=5, measures = ['rmse'])

# %%
gscv.fit(data)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
gscv.best_params
# Out:
# {'rmse': {'k': 10,
#   'min_k': 3,
#   'sim_options': {'name': 'pearson', 'user_based': True}}}

# %%
gscv.best_score
# Out:
# {'rmse': 0.49079114002207086}

# %%
knn_basic_user = KNNBasic(**gscv.best_params)

# %%
knn_basic_user.fit(trainset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
prediction = knn_basic_user.test(testset)
accuracy.rmse(prediction)
# Out:
# RMSE: 0.5065
# 0.5064576520368301

# %% [markdown]
# we have a model with an Root Mean Square Error (RMSE) is 0.5064576520368301

# %% [markdown]
# then, build a recommendation system for single user

# %%
def recom_cf(df, user, n, model):
    rated = df[df['user_id'] == user]['song_id']
    
    unrated = []
    for id in df['song_id'].unique():
        if id not in rated:
            if id not in unrated:
                unrated.append(id)
    
    est_rating = []
    for id in unrated:
        est_rating.append(model.predict(user, id).est)
    
    ori = []
    for id in unrated:
        ori.append(song_dict[id])

    return pd.DataFrame({'song_id': unrated,
                        'est_rating': est_rating,
                        'title': ori}).sort_values('est_rating', ascending=False).iloc[:n].reset_index(drop=True)

# %% [markdown]
# Let's try the top 10 recommendation songs system with someone who has user_id 8557

# %%
recom_cf(song_us, 8557, 10, knn_basic_user)
# Out:
#    song_id  est_rating                                              title
# 0     3165    1.188636                              (Mockingbird, Eminem)
# 1     3398    1.188636                          (Cold Water, Damien Rice)
# 2     2621    1.188636                          (Excuse Me Mr., No Doubt)
# 3      995    1.188636  (Kept It Too Real (Amended Album Version), Plies)
# 4     6852    1.188636                        (June Evenings, Air France)
# 5     6784    1.188636                       (Mad World, Tears For Fears)
# 6     9105    1.188636                            (Rest, The Temper Trap)
# 7     7775    1.188636                      (Weenie Beenie, Foo Fighters)
# 8     2990    1.188636              (Right Down The Line, Gerry Rafferty)
# 9     6006    1.188636   (Let's Go All The Way (Short Blix Mix), Sly Fox)
